# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/My Drive/Colab Notebooks/TuckER-master/main.py" --dataset MT3K --num_iterations 500 --batch_size 128 --lr 0.0005 --dr 1.0 --edim 200 --rdim 30 --input_dropout 0.3 --hidden_dropout1 0.4 --hidden_dropout2 0.5 --label_smoothing 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.013088733827074369
# Validation:
# Number of data points: 2820
# Hits @10: 0.1322695035460993
# Hits @3: 0.06205673758865248
# Hits @1: 0.036170212765957444
# Mean rank: 389.2918439716312
# Mean reciprocal rank: 0.06988006213154277
# Test:
# Number of data points: 2820
# Hits @10: 0.1322695035460993
# Hits @3: 0.06205673758865248
# Hits @1: 0.036170212765957444
# Mean rank: 389.2918439716312
# Mean reciprocal rank: 0.06988006213154277
# 0.5573558807373047
# 145
# 0.05622100830078125
# 0.013079018083711464
# Validation:
# Number of data points: 2820
# Hits @10: 0.13297872340425532
# Hits @3: 0.06170212765957447
# Hits @1: 0.03546099290780142
# Mean rank: 387.781914893617
# Mean reciprocal rank: 0.06951205545023724
# 146
# 0.05434012413024902
# 0.012885957583785057
# Validation:
# Number of data points: 2820
# Hits @10: 0.13297872340425532
# Hits @3: 0.06205673758865248
# Hits @1: 0.03546099290780142
# ...

# %%
# !ls /content/gdrive/'My Drive'/
# Out:
# 'Colab Notebooks'    'My docs'		  share-pc
# 'Courses Fall 19'     notes		  summary.xlsx
# 'Courses Spring 20'   others		 'Tania USA journey.gsheet'
# 'Fall 2020'	      Research		  tax
#  Important_RPI	     'Self Improvement'  'When We Meet.gsheet'

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/My Drive/Colab Notebooks/TuckER-master/main.py" --dataset MT3K --num_iterations 1 --batch_size 128 --lr 0.0005 --dr 1.0 --edim 200 --rdim 30 --input_dropout 0.3 --hidden_dropout1 0.4 --hidden_dropout2 0.5 --label_smoothing 0.1
# Out:
# python3: can't open file '/content/gdrive/My Drive/Colab Notebooks/TuckER-master/main.py': [Errno 2] No such file or directory
